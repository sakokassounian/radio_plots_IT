# %% [markdown]
# # 1. Import the data and packages

# %% [markdown]
# The radio plot is based on comapring different people and figuring out what is the perfect role they can perform.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("results.csv")

# %%
df
# Out:
#                        Categories  Sergio  Pamella  Rodolf  Angelika  \
# 0                          ML Ops     2.0      2.0     0.0       0.0
# 1             ML Model Deployment     2.0      2.0     1.0       0.0
# 2   Statistics and ML Development     4.5      3.0     1.0       3.0
# 3                       Inference     4.5      3.0     2.0       3.0
# 4                 Experimentation     4.5      3.0     2.0       3.0
# 5           Metrics and Reporting     3.0      5.0     5.0       5.0
# 6               Business Insights     4.0      4.0     4.0       5.0
# 7              Data Visualization     3.0      4.0     4.5       5.0
# 8                    Storytelling     4.5      4.5     4.5       4.5
# 9                      Data Tools     2.0      3.0     1.0       3.0
# 10                      Databases     2.0      3.0     2.0       3.0
# 11                 Data Pipelines     2.0      3.0     2.0       3.0
# 12      Financial crime knowledge     1.0      3.0     2.0       5.0
#
#     ML engineer  Data Scientist  Data Analyst  Data Engineer
# 0             5               2             1              3
# 1             5               3             1              2
# 2             4               5             2              1
# 3             2               5             2              1
# 4             2               4             3              1
# 5             1               3             5              1
# 6             1               2             5              1
# 7             1               2             5              1
# 8             1               2             5              1
# 9             1               1             1              5
# 10            2               1             1              5
# 11            3               1             1              5
# 12            1               5             5              1

# %% [markdown]
# # 2. Process the data

# %% [markdown]
# We'll split data into 2 tables, of people and professions.

# %%
prof = ['ML engineer','Data Scientist', 'Data Analyst', 'Data Engineer']
colors = ['yellow','blue','red','green']
df_prof = df[prof].to_numpy().T.tolist()

people = list(set(df.columns.tolist()) - set(prof).union({"Categories"}))
df_people = df[people].to_numpy().T.tolist()

# %%
# Categories (Axes)
categories = df.Categories

N = len(categories)
angles = np.linspace(0, 2 * np.pi, N, endpoint=False).tolist()
angles.append(angles[0])  # Closing the loop

# Create the radar chart
fig, axes = plt.subplots(2,2,figsize=(15, 15), subplot_kw=dict(polar=True))


for ax, values, title in zip(axes.flatten(), df_people, people):

    
    # Ensure values wrap around to close the radar chart
    values.append(values[0])  # Closing the loop


    # Plot data
    ax.fill(angles, values, color='blue', alpha=0.25)
    ax.plot(angles, values, color='blue', linewidth=2)
    

    # Set labels
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(categories, fontsize=10)
    
    # Show plot
    ax.set_title(title,fontsize=20)



plt.tight_layout()    
plt.show()

# %%
# Create the radar chart
fig, axes = plt.subplots(2,2,figsize=(15, 15), subplot_kw=dict(polar=True))

for ax, values, title,col in zip(axes.flatten(), 
                             df_prof, 
                             prof,
                             colors):

    
    # Ensure values wrap around to close the radar chart
    values.append(values[0])  # Closing the loop


    # Plot data
    ax.fill(angles, values, color=col, alpha=0.25)
    ax.plot(angles, values, color=col, linewidth=2)
    
    # Set labels
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(categories, fontsize=10)
    
    # Show plot
    ax.set_title(title,fontsize=20)
plt.tight_layout()    
plt.show()
